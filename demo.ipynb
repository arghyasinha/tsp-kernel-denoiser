# %%
from thm_5 import *

# %%
image_name = get_image_name(image_number)
image = get_image(image_number)
# Out:
# images/Set12/05.png
# image.size:  (256, 256)
# max of original image :  243
# min of original image :  16

# %%
analyze_application_kwargs(image= image, image_name=image_name, application_kwargs_list=[0.1,0.5,0.9])
# Out:
# prob_observe: 0.1, P_operator_norm: 0.9273710613442483, rhs: 0.9948922661520384, lambda_2: 0.9738617606254335, lambda_2^2: 0.9484067288084691, inequality_holds: True
# prob_observe: 0.5, P_operator_norm: 0.8984647575843795, rhs: 0.9715535243906049, lambda_2: 0.9708410644931912, lambda_2^2: 0.9425323725062726, inequality_holds: True
# prob_observe: 0.9, P_operator_norm: 0.8138797897747635, rhs: 0.954504530983582, lambda_2: 0.9741349329256742, lambda_2^2: 0.9489388675461078, inequality_holds: True
